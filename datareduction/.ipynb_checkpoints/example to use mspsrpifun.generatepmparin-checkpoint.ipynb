# %%
import mspsrpifun

# %% [markdown]
# Before you create the instance below, make sure you change the environment variables accordingly to yours. I'll make it easier to adapt to different environment vaiables later.

# %%
a=mspsrpifun.generatepmparin('J1853+1303')
# Out:
# J1852+1426 IBC01535

# %%
a.write_out_final_pmpar_in()
# Out:
# J1852+1426 IBC01535
# 4.0 32.0
# 20.0 32.0
# 23.0 29.0
# 12.0 39.0
# 10.0 45.0
# 10.0 29.0
# 9.0 50.0
# 23.0 5.0
# J1852+1426 IBC01535
# 4.0 32.0
# 18:53:57.3180277
# 13:03:44.052522
# J1852+1426 IBC01535
# 20.0 32.0
# 18:53:57.3179441
# 13:03:44.050623
# J1852+1426 IBC01535
# 23.0 29.0
# 18:53:57.3179062
# 13:03:44.046496
# J1852+1426 IBC01535
# 12.0 39.0
# 18:53:57.3178907
# 13:03:44.047291
# J1852+1426 IBC01535
# 10.0 45.0
# 18:53:57.3178875
# 13:03:44.047244
# J1852+1426 IBC01535
# 10.0 29.0
# 18:53:57.3178842
# 13:03:44.047251
# J1852+1426 IBC01535
# 9.0 50.0
# 18:53:57.3178698
# 13:03:44.047160
# J1852+1426 IBC01535
# 23.0 5.0
# 18:53:57.3177720
# 13:03:44.045116
# ['/fred/oz002/hding/mspsrpi//processing/J1853+1303/bd179k0/bd179k0_IBC01535.difmap.jmfit.stokesi.stats']
# The map center for the target is:
#
# J1852+1426 IBC01535
# ('18:53:57.3181387', '13:03:44.0519259')
# Not a dual-phscal configuration; go with normal separation
# The map center for the target is:
#
# ...

# %%
a.bootstrap_pmpar('J1853+1303.pmpar.in', 10000, 'mu_a=1.65+-0.04 mu_d=-2.89+-0.06', True)
# Out:
# 18:53:57.317916
# 13:03:44.047019
# 1.642873
# -2.938338
# -0.260135
# progress:0.0%
# 18:53:57.318008
# 13:03:44.047069
# 1.632783
# -2.855392
# -1.713576
# progress:0.0%
# 18:53:57.317817
# 13:03:44.047013
# 1.665312
# -2.876281
# 1.059733
# progress:0.0%
# 18:53:57.317910
# 13:03:44.047165
# 1.637777
# -2.990795
# -0.241345
# progress:0.0%
# 18:53:57.317813
# 13:03:44.047075
# 1.669082
# -2.811435
# 1.109474
# progress:0.0%
# 18:53:57.317794
# 13:03:44.047020
# 1.652524
# -2.939837
# 1.235889
# progress:0.0%
# 18:53:57.317979
# 13:03:44.047103
# 1.640307
# -2.871090
# -1.659418
# progress:0.0%
# 18:53:57.318000
# 13:03:44.047405
# 1.724232
# -2.885348
# -1.706720
# progress:0.0%
# 18:53:57.317856
# 13:03:44.047131
# 1.583708
# -2.876134
# 0.354717
# progress:0.0%
# 18:53:57.317839
# 13:03:44.046985
# 1.569309
# -2.892618
# 0.729632
# progress:0.1%
# 18:53:57.318005
# 13:03:44.047034
# 1.642126
# -2.880241
# -1.533572
# progress:0.1%
# 18:53:57.318010
# 13:03:44.047422
# 1.662779
# ...

# %%
a.bootstrapped_sample2measured_value()
# Out:
# (array([-0.260135, -1.713576,  1.059733, ...,  1.252187, -0.281977,
#          0.540029]),
#  array([1.642873, 1.632783, 1.665312, ..., 1.680846, 1.641858, 1.647848]),
#  array([-2.938338, -2.855392, -2.876281, ..., -2.797689, -2.883621,
#         -2.756342]),
#  array([18.89925498, 18.899255  , 18.89925495, ..., 18.89925494,
#         18.89925497, 18.89925496]),
#  array([13.06223528, 13.0622353 , 13.06223528, ..., 13.06223528,
#         13.06223534, 13.06223529]))

# %% [markdown]
# Then J1853+131.bootstrap.estimates.out would be made. The next step is plot making with plot_three_histrograms_with_bootstrap_results() or plot_five_histograms_with_bootstrap_results()
